# %% [markdown]
# import pandas as pd
# auto = pd.read_csv(r'C:\Users\catba\Documents\Universitetet i Oslo\Våren 2025\PSY9511 Machine learning\Data sets\ALL CSV FILES - 2nd Edition\Auto.csv')
# print(auto.head())

# %% [markdown]
# print(auto.loc[[5, 8, 9, 10]])

# %% [markdown]
# last_three_columns = auto.iloc[:, -3:]
# print(last_three_columns)

# %% [markdown]
# five_cylinder_cars = auto[auto['cylinders'] == 5]
# print(five_cylinder_cars)

# %% [markdown]
# import numpy as np

# %% [markdown]
# !pip install matplotlib

# %% [markdown]
# import matplotlib.pyplot as plt

# %% [markdown]
# # Creating a vector of 100 standard normally distributed numbers
# numbers = np.random.standard_normal(100)
#
# # Rounding the numbers to integers for tidiness
# rounded_numbers = np.round(numbers).astype(int)
#
# # Creating a histogram
# plt.hist(rounded_numbers, bins='auto', edgecolor='black')
#
# # Adding labels and title
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.title('Histogram')
